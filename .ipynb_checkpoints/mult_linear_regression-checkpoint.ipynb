# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
url = 'https://data.montgomerycountymd.gov/resource/v76h-r7br.csv?$limit=350000&$offset=0'

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    calendar_year  cal_month_num       supplier item_code  \
# 0           2026              7  20705 IMPORTS    180424
# 1           2026              7  20705 IMPORTS    246789
# 2           2026              7  20705 IMPORTS    180113
# 3           2026              7  20705 IMPORTS    180298
# 4           2026              7  20705 IMPORTS    246788
#
#                                 item_description item_type  rtl_sales  \
# 0               FENTO BICO DA RAN ALBARINO 750ML      WINE        0.0
# 1         MIHOVI EST BROAD LEAVED MELNIK - 750ML      WINE        0.0
# 2  DOM DU FOURNIER SIGNARGUES CDR VILLAGES 750ML      WINE        0.0
# 3     AGRICOLA LA PORTERA TARDANO GARNACHA 750ML      WINE        0.0
# 4      MIHOVI EST KERASTUDA SEL KEPAUYDA - 750ML      WINE        0.0
#
#    rtl_transfers  whs_sales
# 0            0.0        1.0
# 1            0.0        1.0
# 2            0.0        1.0
# 3            0.0        1.0
# 4            0.0        1.0

# %%
df.shape
# Out:
# (330080, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330080 entries, 0 to 330079
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   calendar_year     330080 non-null  int64
#  1   cal_month_num     330080 non-null  int64
#  2   supplier          329887 non-null  object
#  3   item_code         330080 non-null  object
#  4   item_description  330080 non-null  object
#  5   item_type         330079 non-null  object
#  6   rtl_sales         330075 non-null  float64
#  7   rtl_transfers     330080 non-null  float64
#  8   whs_sales         330080 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 22.7+ MB

# %%
df.describe()
# Out:
#        calendar_year  cal_month_num      rtl_sales  rtl_transfers  \
# count  330080.000000  330080.000000  330075.000000  330080.000000
# mean     2018.952466       6.428536       6.984240       6.930010
# std         2.171479       3.344680      31.488784      30.173479
# min      2017.000000       1.000000      -6.490000     -38.490000
# 25%      2017.000000       3.000000       0.000000       0.000000
# 50%      2019.000000       7.000000       0.290000       0.000000
# 75%      2019.000000       9.000000       3.270000       3.000000
# max      2026.000000      12.000000    2923.000000    1990.830000
#
#            whs_sales
# count  330080.000000
# mean       25.565961
# std       250.547317
# min     -7800.000000
# 25%         0.000000
# 50%         1.000000
# 75%         5.000000
# max     18317.000000

# %%
df.rtl_transfers.max()
# Out:
# np.float64(1990.83)

# %%
plt.hist(df['rtl_transfers'])
plt.show()

# %%
df.rtl_sales.value_counts()
# Out:
# rtl_sales
# 0.00      132247
# 0.08       11004
# 0.17        7281
# 0.16        6257
# 0.24        4073
#            ...
# 112.53         1
# 121.53         1
# 138.50         1
# 78.58          1
# 52.30          1
# Name: count, Length: 10918, dtype: int64

# %%
counts = df.item_type.value_counts()

counts.plot(kind='bar', figsize=(8,6))
plt.xlabel('Item Type')
plt.ylabel('Count')
plt.title('Value Counts of Item Types')
plt.show()
